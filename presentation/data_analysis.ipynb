# %% [markdown]
# # 5. Data Analysis
#
# - colab link: https://colab.research.google.com/drive/1Mg8IkZLA2q5rHxOhjkIPzn7Pm2xlb7OC?usp=sharing

# %% [markdown]
# ## Libraries
# - Introduction to libraries
#     - collections of pre-written code that useers can call upon to optimize tasks
#     - they provide a suite of functions and tools to handle common tasks which saves time and effort
#
# - why use libraries?
#     - enables developers to avoid "reinventing the wheel" by using this pre-buit and optimized code for common tasks
#     - pandas, NumPy, Matplotlib, scikit-learn, seaborn etc
#
# - how to use them
#     - by importing these libearies
#     - example: import pandas as pd

# %% [markdown]
# # pandas
# - pandas is a powerful library for data manipulation and analysis
# - pandas make it easy to read and write data, manipulate it, perform complex operations and visualize it
#
# ![image.png](attachment:image.png)

# %%
# reading a file

# %% [markdown]
# ##  Numpy
# - numpy is the fundametal package for scientic computing with python
# - numpy array-oriented computing is efficient and helps in performing mathematical computations easily and swiftly

# %%
#numpy operations 
import numpy as np

array =np.array([2,3,4,5,6,7])

# %%
# 2d array 
array=np.array([[2,3,4],[5,6,7]])

# %% [markdown]
# ## Matplotlib
# - matplotlib is a plotting library used for creating static animated and interactive visualization in python
# - it provides a wide range of plots scatter plots, bar charts, histograms and more.
# - Matplotlib integrates well with pandas and numpy, making it an essential tool for data visualization
# - seaborn package - built on matplotlib but provides high-level interface for drawing  attractive statistical graphicals, similar to the ggplot2 library in R.

# %% [markdown]
# # Data Analysis Tasks

# %%
# import necessary libraries

# %% [markdown]
# ## Task 1: Load the dataset

# %%
# specify the file path 
# read the CSV file into a pandas dataframe 
# displat the first few rows of the Data frame

# %% [markdown]
# ## Task 2: Data Cleaning and Preparation

# %%
# 1. Check for missing values in the datasets
# 2. Check the data types of all the columns

# %%
# imputing the numeric data
# laptop_data['Price_euros'].fillna(laptop_data['Price_euros'].mean())

# %%
# imputing categorical data 
# print(laptop_data['Company'].value_counts())
# laptop_data['Company'].fillna('Dell')

# %%
# functions to clean the data
import re

# %%
# add new columns to the dataset with updated values

# %% [markdown]
# ## task 3: Exploratory data Analysis (EDA) and Visualization

# %%
# box plot to check price distribution

# %%
# Average price by brand

# %%
# Average relation between CPU manufacturer and price

# %%
# bar plot the relation between GPU and price

# %%
# line plot between screen inches and price
